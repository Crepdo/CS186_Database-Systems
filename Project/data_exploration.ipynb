# %% [markdown]
# **A data science experiment using data from the KDD 2010 Educational Data Mining Challenge**
#
# The aim of this IPython Notebook is to give you a sense of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import random

# %%
# Get the data:
train_filepath = 'data/train.csv'
traindata = pd.read_table(train_filepath)

# %%
traindata.columns
# Out:
# Index(['Row', 'Anon Student Id', 'Problem Hierarchy', 'Problem Name',
#        'Problem View', 'Step Name', 'Step Start Time',
#        'First Transaction Time', 'Correct Transaction Time', 'Step End Time',
#        'Step Duration (sec)', 'Correct Step Duration (sec)',
#        'Error Step Duration (sec)', 'Correct First Attempt', 'Incorrects',
#        'Hints', 'Corrects', 'KC(Default)', 'Opportunity(Default)'],
#       dtype='object')

# %%
# Inspect some of the training data
traindata.head(10)
# Out:
#     Row Anon Student Id                Problem Hierarchy Problem Name  \
# 0  9938      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 1  9939      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 2  9940      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 3  9941      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 4  9942      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 5  9943      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 6  9944      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 7  9945      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 8  9946      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 9  9947      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
#
#    Problem View       Step Name        Step Start Time First Transaction Time  \
# 0             1            R1C1  2005-09-09 12:23:34.0  2005-09-09 12:24:07.0
# 1             1            R1C2  2005-09-09 12:24:07.0  2005-09-09 12:24:22.0
# 2             1            R3C1  2005-09-09 12:24:22.0  2005-09-09 12:25:16.0
# 3             1            R3C2  2005-09-09 12:25:40.0  2005-09-09 12:25:51.0
# 4             1            R4C1  2005-09-09 12:27:24.0  2005-09-09 12:27:30.0
# 5             1            R5C1  2005-09-09 12:27:30.0  2005-09-09 12:27:41.0
# 6             1            R6C1  2005-09-09 12:27:41.0  2005-09-09 12:28:41.0
# 7             1            R7C2  2005-09-09 12:28:50.0  2005-09-09 12:28:58.0
# 8             1  ValidEquations  2005-09-09 12:31:39.0  2005-09-09 12:31:52.0
# 9             1   7/10*X = 1400  2005-09-09 12:31:52.0  2005-09-09 12:32:28.0
#
#   Correct Transaction Time          Step End Time  Step Duration (sec)  \
# 0    2005-09-09 12:24:07.0  2005-09-09 12:24:07.0                 33.0
# 1    2005-09-09 12:24:22.0  2005-09-09 12:24:22.0                 15.0
# 2    2005-09-09 12:25:40.0  2005-09-09 12:25:40.0                 78.0
# 3    2005-09-09 12:27:24.0  2005-09-09 12:27:24.0                104.0
# 4    2005-09-09 12:27:30.0  2005-09-09 12:27:30.0                  6.0
# 5    2005-09-09 12:27:41.0  2005-09-09 12:27:41.0                 11.0
# 6    2005-09-09 12:28:41.0  2005-09-09 12:28:41.0                 60.0
# 7    2005-09-09 12:28:58.0  2005-09-09 12:28:58.0                  8.0
# 8    2005-09-09 12:31:52.0  2005-09-09 12:31:52.0                 13.0
# 9    2005-09-09 12:32:35.0  2005-09-09 12:32:35.0                 43.0
#
#    Correct Step Duration (sec)  Error Step Duration (sec)  \
# 0                         33.0                        NaN
# 1                         15.0                        NaN
# 2                          NaN                       78.0
# 3                          NaN                      104.0
# 4                          6.0                        NaN
# 5                         11.0                        NaN
# 6                         60.0                        NaN
# 7                          8.0                        NaN
# 8                         13.0                        NaN
# 9                          NaN                       43.0
#
#    Correct First Attempt  Incorrects  Hints  Corrects  \
# 0                      1           0      0         1
# 1                      1           0      0         1
# 2                      0           2      0         1
# 3                      0           4      9         1
# 4                      1           0      0         1
# 5                      1           0      0         1
# 6                      1           0      0         1
# 7                      1           0      0         1
# 8                      1           0      0         2
# 9                      0           1      0         1
#
#                                          KC(Default) Opportunity(Default)
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                    Define Variable                    1
# 3  Using small numbers~~Write expression, positiv...              1~~1~~1
# 4                                   Entering a given                    1
# 5                                   Entering a given                    2
# 6                                   Entering a given                    3
# 7                                   Entering a given                    4
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN

# %%
traindata['Step Name']
# Out:
# 0         R1C1
# 1         R1C2
# 2         R3C1
# 3         R3C2
# 4         R4C1
#           ...
# 232739    R5C1
# 232740    R1C2
# 232741    R2C2
# 232742    R3C2
# 232743    R6C2
# Name: Step Name, Length: 232744, dtype: object

# %% [markdown]
# Let's begin asking some basic questions of the data
#
# ### How many students are interacting with the system?

# %%
# Take the column of anonimized student IDs and count the number of unique entries
print('Number of students: ', len(np.unique(traindata['Anon Student Id'])))
# Out:
# Number of students:  174

# %% [markdown]
# ### How long does it take a student to solve any problem step on average?

# %%
csd = traindata['Correct Step Duration (sec)']
csd.describe()
# Out:
# count    181599.000000
# mean         17.924024
# std          35.179534
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          17.000000
# max        1067.000000
# Name: Correct Step Duration (sec), dtype: float64

# %% [markdown]
# So ignoring all the students that did not solve a problem step correctly, the average duraction for any problem step was about 18 seconds.
#
# Let's histogram this data to see the distribution.

# %%
# %matplotlib inline
hist = plt.hist(np.array(csd.dropna()),bins=100,density=True,log=False,range=(0,100))
# dropna: remove missing values
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Fraction')
plt.show()

# %%
counts, bins = hist[0], hist[1]
cdf = np.cumsum(counts)
plt.plot(bins[1::], cdf)
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Cumulative fraction')
plt.axis((0,100,0,1.0))
plt.show()

# %% [markdown]
# The histogram shows visually what mere statistics hints at. The distribution of students is heavily weighted towards those who are solving problems in under 20 seconds. The cumulative distribution function (CDF) shows that roughly 80% of successful students solve the problem within 20 seconds. After 40 seconds, 90% of successful students have finished the problem. Almost no students take longer than 80 seconds.

# %% [markdown]
# ### Completion time by problem
#
# OK, let's ask a slightly harder question: how are students doing problem by problem? The answer will take several parts.
#
# First, let's get the number of unique problems

# %%
# The unique identifier for each problem is the 'Problem Name'
problems = traindata['Problem Name']
# Out:
# 0         PROP04
# 1         PROP04
# 2         PROP04
# 3         PROP04
# 4         PROP04
#            ...
# 232739     NOV05
# 232740     NOV05
# 232741     NOV05
# 232742     NOV05
# 232743     NOV05
# Name: Problem Name, Length: 232744, dtype: object

# %%
# Get just the uniques
problems = np.unique(problems)
print('Number of unique problems: ', len(problems))
problems
# Out:
# Number of unique problems:  1021
# array(['1PTB02', '1PTB03', '1PTB04', ..., 'YLT250', 'YLT2X-5', 'YLT3X+5'],
#       dtype=object)

# %% [markdown]
# Then, let's compute which problems need the largest time on average.

# %%
pmedian_times = {}
for p in problems:
    pmedian_times[p] = traindata[traindata['Problem Name'] == p]['Correct Step Duration (sec)'].median()

# %%
import operator

# %%
sorted_times = sorted(pmedian_times.items(), key=operator.itemgetter(1), reverse=True)

# %%
print("The hardest top-5 problem and its average correct duration (sec).")
print(sorted_times[:5])

print("The earliest top-5 problem and its average correct duration (sec).")
print(sorted_times[len(sorted_times)-5:])
# Out:
# The hardest top-5 problem and its average correct duration (sec).
# [('JAN13C', 65.0), ('TRANSFORMN022', 32.0), ('EG-FACTOR45', 30.0), ('BH1T33B', 25.0), ('EG-FACTOR47', 23.0)]
# The earliest top-5 problem and its average correct duration (sec).
# [('TRANSFORMN013', 1.25), ('TRANSFORMN014', 1.25), ('TRANSFORMG042', 1.0), ('TRANSFORMN004', 1.0), ('TRANSFORMN005', 1.0)]

# %% [markdown]
# Statistical results of problem difficulty

# %%
hist = plt.hist(np.array(list(pmedian_times.values())),bins=15,density=True,log=False,range=(0,25))
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Number')
plt.show()

# %% [markdown]
# If we take the time to correct answer as the difficulty of a problem, the histogram shows visually the difficulties of all the problems.

# %% [markdown]
# ### Conclusion
# There are many other interesting characteristic in this dataset.
# Like,
# * After some practices, students may become better at solving problems.
# * Same problem step for different students may request different knowledge components. Or for some problems, there is only one correct knowledge components
#
# These may be some things you need to take consider into for the feature engineering part. We leave them for you to explore deeper.

# %%
import pandas as pd
est_path='data/train_cleaned.csv'
test=pd.read_csv(test_path,on_bad_lines='skip')
for col in test:
    try: col = pd.to_numeric(col)
    except: continue
print (test.dtypes)
ax = test.plot(kind='hist')
# Out:
# Anon Student Id            int64
# Problem Hierarchy          int64
# Step Name                  int64
# Problem Name               int64
# Problem View               int64
# Correct First Attempt      int64
# Student CFA                int64
# Problem CFA                int64
# Step CFA                   int64
# KC CFA                   float64
# dtype: object

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=10, ncols=1)
title_list = []
for col in test:
    title_list.append(col)
print(title_list)
i = 0
for title in title_list:
    test[title].plot(kind='hist', title=title,ax=axes[i],figsize=(10,40))
    i+=1
# test.plot(kind='hist',subplots=True, title=title_list,figsize=(10,20))
# Out:
# ['Anon Student Id', 'Problem Hierarchy', 'Step Name', 'Problem Name', 'Problem View', 'Correct First Attempt', 'Student CFA', 'Problem CFA', 'Step CFA', 'KC CFA']

# %%
train_path='data/train.csv'
train_data=pd.read_table(train_path)
step_CFA={}
count = 0
for x,gr in train_data.groupby(['Step Name']):
    if count==4:
        display(gr)
        display(gr[gr['Correct First Attempt']==1])
    count+=1
    step_CFA[x]=len(gr[gr['Correct First Attempt']==1])
mean_step_CFA=np.mean(list(step_CFA.values())) # TODO: reasonable?
train_data['Step CFA']=train_data['Step Name'].apply(lambda x: step_CFA[x])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Cpdo\Desktop\database\git_ver\CS186_Database-Systems\Project\data_exploration.ipynb Cell 29 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Cpdo/Desktop/database/git_ver/CS186_Database-Systems/Project/data_exploration.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> train_path='data/train.csv'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Cpdo/Desktop/database/git_ver/CS186_Database-Systems/Project/data_exploration.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> train_data=pd.read_table(train_path)
#       <a href='vscode-notebook-cell:/c%3A/Users/Cpdo/Desktop/database/git_ver/CS186_Database-Systems/Project/data_exploration.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> step_CFA={}
#       <a href='vscode-notebook-cell:/c%3A/Users/Cpdo/Desktop/database/git_ver/CS186_Database-Systems/Project/data_exploration.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> count = 0
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\io\parsers\readers.py:779, in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     764 kwds_defaults = _refine_defaults_read(
#     765     dialect,
#     766     delimiter,
#    (...)
#     775     defaults={"delimiter": "\t"},
#     776 )
#     777 kwds.update(kwds_defaults)
# --> 779 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\Cpdo\.conda\envs\DL\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train.csv'
